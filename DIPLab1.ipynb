# %%
import cv2
import matplotlib.pyplot as plt
img= cv2.imread('/content/1st-Image.jpg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
print("img.shape: ", img.shape)
plt.imshow(img)
plt.title("Acquired image")
plt.axis('off')
# Out:
# img.shape:  (6720, 4480, 3)
# (np.float64(-0.5), np.float64(4479.5), np.float64(6719.5), np.float64(-0.5))

# %%
gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
plt.figure(figsize=(5,5))
plt.imshow(gray, cmap='gray')
plt.title("Image Divided into Grid (pixel Representation)")
step = 100

for i in range(0, gray.shape[0], step):
  plt.axhline(i, color='orange', linewidth=0.6)

for j in range(0, gray.shape[1], step):
  plt.axvline(j, color='white', linewidth=0.6)

plt.axis('off')
plt.show()

# %%
print("Pixel intensity values (sample): \n")
print(gray[0:10, 0:10])
# Out:
# Pixel intensity values (sample):
#
# [[121  89  60  52  51  46  43  45  45  44]
#  [121  90  61  52  51  46  43  45  45  44]
#  [122  91  62  53  52  47  43  45  45  44]
#  [124  92  63  54  53  47  44  45  45  44]
#  [125  93  64  55  53  48  44  46  45  44]
#  [126  95  65  56  54  48  44  46  45  44]
#  [127  96  66  56  54  48  44  46  45  44]
#  [128  96  66  57  55  49  45  46  45  44]
#  [130 103  71  54  50  48  44  41  42  44]
#  [129 103  73  56  51  49  46  45  42  44]]

# %%
sampled =cv2.resize(gray, (80,80))

plt.subplot(1,2,1)
plt.imshow(gray, cmap='gray')
plt.title("Original Image")
plt.axis('off')

plt.subplot(1,2,2)
plt.imshow(sampled, cmap='gray')
plt.title("Sampled Image \n(Reduced Resolution)")
plt.axis('off')

plt.show()

# %%
import numpy as np
levels=25

quantized= np.floor(gray / (256/levels)) * (256/levels)
quantized = quantized.astype(np.uint8)

plt.figure(figsize=(10,4))

plt.subplot(1,2,1)
plt.imshow(gray, cmap='gray')
plt.title("Original Image")
plt.axis('off')

plt.subplot(1,2,2)
plt.imshow(quantized, cmap='gray')
plt.title("Quantized Image \n(16 Gray Colors)")
plt.axis('off')

plt.show()

# %%
print('Original image:\n', img[0:10, 0:10])
# Out:
# Original image:
#  [[[126 114 132]
#   [ 94  82 100]
#   [ 65  53  71]
#   [ 56  46  63]
#   [ 55  45  62]
#   [ 48  40  57]
#   [ 43  37  54]
#   [ 43  40  56]
#   [ 43  40  55]
#   [ 40  40  54]]
#
#  [[126 114 132]
#   [ 95  83 101]
#   [ 66  54  72]
#   [ 56  46  63]
#   [ 55  45  62]
#   [ 48  40  57]
#   [ 43  37  54]
#   [ 43  40  56]
#   [ 43  40  55]
